# %% [markdown]
# # Stream de dados do Twitter com MongoDB, Pandas e Scikit Learn

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %%
# Adicione aqui a sua Consumer Key
consumer_key = 'xxxxxxxxxxxxxxxxxxxxxxxxx'

# %%
# Adicione aqui a sua Consumer Secret
consumer_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'

# %%
# Adicione aqui seu Access Token
access_token = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os Streams de Dados do Twitter e armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection 'col'
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Fri Feb 23 20:09:46 +0000 2018', 'id_str': '967129376964972546', 'text': '4 Full Days of Training, Talks, Workshop and Networking on all the latest in AI and Data Science at #ODSC East 2018… https://t.co/WTtOy2UMK6', '_id': ObjectId('5a907509c693cd1b48cabe53')}
# {'created_at': 'Fri Feb 23 20:09:46 +0000 2018', 'id_str': '967129377132765189', 'text': 'made a thing in Drawbot to make rotating desktop wallpapers of quotes and things for inspiration.  #inspiration… https://t.co/z4MRoMRRE8', '_id': ObjectId('5a907509c693cd1b48cabe54')}
# {'created_at': 'Fri Feb 23 20:09:47 +0000 2018', 'id_str': '967129380702089216', 'text': '@KikiDlamini The meaning of life is just so relative and monty python could  not figure out the meaning of life', '_id': ObjectId('5a907509c693cd1b48cabe55')}
# {'created_at': 'Fri Feb 23 20:09:47 +0000 2018', 'id_str': '967129382245584896', 'text': 'Scaling up data quality. Start small but think big. https://t.co/gvPkfRPp3z', '_id': ObjectId('5a90750ac693cd1b48cabe56')}
# {'created_at': 'Fri Feb 23 20:09:49 +0000 2018', 'id_str': '967129387807092736', 'text': 'RT @ericasadun: Pop a little Python Inter-Op into your Playground: https://t.co/taePkzC7f5 (9.3b3 only)', '_id': ObjectId('5a90750bc693cd1b48cabe57')}
# {'created_at': 'Fri Feb 23 20:09:51 +0000 2018', 'id_str': '967129396430757889', 'text': 'RT @ProgrammingWrld: Pay what you want for 50+ hours of Python training https://t.co/vk3pzicSIB https://t.co/AsBIUKwqXI', '_id': ObjectId('5a90750dc693cd1b48cabe58')}
# {'created_at': 'Fri Feb 23 20:09:53 +0000 2018', 'id_str': '967129406052413440', 'text': 'RT @janhjensen: Awesome Python Chemistry https://t.co/sgl59EAQEO #compchem', '_id': ObjectId('5a90750fc693cd1b48cabe59')}
# {'created_at': 'Fri Feb 23 20:09:53 +0000 2018', 'id_str': '967129407168176128', 'text': "With the @sloansportsconf going on right now I hope there's some discussion over what $MSG has done with their busi… https://t.co/92ra3h55zo", '_id': ObjectId('5a90750fc693cd1b48cabe5a')}
# {'created_at': 'Fri Feb 23 20:09:57 +0000 2018', 'id_str': '967129424247353345', 'text': 'RT @northumbriana: This is a real BBC documentary from 1989 on the Guards Division, but it could easily be a Monty Python sketch. https://t…', '_id': ObjectId('5a907513c693cd1b48cabe5b')}
# {'created_at': 'Fri Feb 23 20:09:58 +0000 2018', 'id_str': '967129425635627008', 'text': 'RT @plotlygraphs: ICYMI: Fully interactive D3 violin plots made in R and Python 🎻\nPython: https://t.co/whDPIliTsy\nR: https://t.co/pfYbOsiBt…', '_id': ObjectId('5a907514c693cd1b48cabe5c')}
# {'created_at': 'Fri Feb 23 20:10:02 +0000 2018', 'id_str': '967129442312179713', 'text': '#Python - @property decorator is Python way to use getter and setter; it allows to assign functions used when we get or set value to field', '_id': ObjectId('5a907519c693cd1b48cabe5d')}
# {'created_at': 'Fri Feb 23 20:10:06 +0000 2018', 'id_str': '967129462490923009', 'text': '4 Ways Real-time Big Data Improves Pharma’s Bottom Line https://t.co/hWk0Z8BrWd', '_id': ObjectId('5a90751dc693cd1b48cabe5e')}
# {'created_at': 'Fri Feb 23 20:10:07 +0000 2018', 'id_str': '967129464705601536', 'text': 'Become a WiDS Broadcaster and share the #WiDS2018 @Stanford Livestream with visitors to your website and/or stream… https://t.co/qjPiXWszMV', '_id': ObjectId('5a90751dc693cd1b48cabe5f')}
# {'created_at': 'Fri Feb 23 20:10:07 +0000 2018', 'id_str': '967129465250832386', 'text': 'Python and Django Full Stack Web Developer Bootcamp\n\n☞ https://t.co/EyXIod5E8E\n\n#python https://t.co/jjN5vdyiJo', '_id': ObjectId('5a90751dc693cd1b48cabe60')}
# {'created_at': 'Fri Feb 23 20:10:07 +0000 2018', 'id_str': '967129466198724610', 'text': 'RT @mitpress: Science’s Inference Problem: When Data Doesn’t Mean What We Think It Does https://t.co/0oL6z0Uy1n @nytimesbooks Five Constrai…', '_id': ObjectId('5a90751dc693cd1b48cabe61')}
# {'created_at': 'Fri Feb 23 20:10:07 +0000 2018', 'id_str': '967129466345525250', 'text': 'RT @PulseGhana: Video: Commotion erupts as passengers find huge python in a moving train https://t.co/7rzwuZcSI5 https://t.co/jNyOFsPNxH', '_id': ObjectId('5a90751ec693cd1b48cabe62')}
# {'created_at': 'Fri Feb 23 20:10:10 +0000 2018', 'id_str': '967129476105670656', 'text': 'Check out Drama, the breezy and brilliant new song from @NoMBeMusic &amp; @BigDataBigData. \n\nhttps://t.co/3pTqicFmWm https://t.co/Cm6k3fCiV6', '_id': ObjectId('5a907520c693cd1b48cabe63')}
# {'created_at': 'Fri Feb 23 20:10:10 +0000 2018', 'id_str': '967129477586309121', 'text': 'As machines get smarter, this doesn’t surprise me. https://t.co/YVann7OQKm', '_id': ObjectId('5a907520c693cd1b48cabe64')}
# {'created_at': 'Fri Feb 23 20:10:12 +0000 2018', 'id_str': '967129484532043776', 'text': '… Emergency drills, early warning systems, and mass alert systems helped *a lot*. (This article from January has so… https://t.co/8AWGYyJeH2', '_id': ObjectId('5a907522c693cd1b48cabe65')}
# {'created_at': 'Fri Feb 23 20:10:12 +0000 2018', 'id_str': '967129486042034177', 'text': "@dabeaz In mobile it's very common for a game/app to use a websocket to talk to a server. Using a single process pe… https://t.co/pf3hOLUqpf", '_id': ObjectId('5a907522c693cd1b48cabe66')}
# {'created_at': 'Fri Feb 23 20:10:15 +0000 2018', 'id_str': '967129500457885696', 'text': 'Big Companies Are Embracing Analytics, But Most Still Don’t Have a Data-Driven Culture @HarvardBiz… https://t.co/sg2lQp6PvO', '_id': ObjectId('5a907526c693cd1b48cabe67')}
# {'created_at': 'Fri Feb 23 20:10:17 +0000 2018', 'id_str': '967129506698809345', 'text': '@python NowTime: 2018/02/24 05:10:17.3015\nTweetCount: 519', '_id': ObjectId('5a907527c693cd1b48cabe68')}
# {'created_at': 'Fri Feb 23 20:10:17 +0000 2018', 'id_str': '967129507978100736', 'text': '@python NowTime: 2018/02/24 05:10:17.6045\nTweetCount: 519', '_id': ObjectId('5a907527c693cd1b48cabe69')}
# {'created_at': 'Fri Feb 23 20:10:18 +0000 2018', 'id_str': '967129511547539457', 'text': 'RT @gehlinstitute: "When we think about the role of urban data science in design and planning, we should view it as an instrument that can…', '_id': ObjectId('5a907528c693cd1b48cabe6a')}
# {'created_at': 'Fri Feb 23 20:10:19 +0000 2018', 'id_str': '967129515691466753', 'text': '@python NowTime: 2018/02/24 05:10:19.4431\nTweetCount: 517', '_id': ObjectId('5a907529c693cd1b48cabe6b')}
# {'created_at': 'Fri Feb 23 20:10:20 +0000 2018', 'id_str': '967129521248980992', 'text': "RT @kirstendanis: ✨JOB✨\nAmbitious visual journalists — check out @MarshallProj posting. We're looking for a big thinker and crackerjack edi…", '_id': ObjectId('5a90752bc693cd1b48cabe6c')}
# {'created_at': 'Fri Feb 23 20:10:21 +0000 2018', 'id_str': '967129524696739840', 'text': 'Python 3’s range is more powerful than Python 2’s xrange via @treyhunner https://t.co/Cb6JdYmjGk', '_id': ObjectId('5a90752bc693cd1b48cabe6d')}
# {'created_at': 'Fri Feb 23 20:10:25 +0000 2018', 'id_str': '967129539863371777', 'text': 'Full-Stack Developer | PHP, ASP, Python, HTML, CSS, JS, MSSQL, MySQL, PostgreSQL, Scrum, XP, AI, UI, UX. | https://t.co/oztPrGX6ZL', '_id': ObjectId('5a90752fc693cd1b48cabe6e')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-8f0eed42c826> in <module>()
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
mystream.disconnect()

# %%
# Verificando um documento na collection
col.find_one()
# Out:
# {'_id': ObjectId('5a907509c693cd1b48cabe53'),
#  'created_at': 'Fri Feb 23 20:09:46 +0000 2018',
#  'id_str': '967129376964972546',
#  'text': '4 Full Days of Training, Talks, Workshop and Networking on all the latest in AI and Data Science at #ODSC East 2018… https://t.co/WTtOy2UMK6'}

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
           } for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Fri Feb 23 20:09:46 +0000 2018
# 1   Fri Feb 23 20:09:46 +0000 2018
# 2   Fri Feb 23 20:09:47 +0000 2018
# 3   Fri Feb 23 20:09:47 +0000 2018
# 4   Fri Feb 23 20:09:49 +0000 2018
# 5   Fri Feb 23 20:09:51 +0000 2018
# 6   Fri Feb 23 20:09:53 +0000 2018
# 7   Fri Feb 23 20:09:53 +0000 2018
# 8   Fri Feb 23 20:09:57 +0000 2018
# 9   Fri Feb 23 20:09:58 +0000 2018
# 10  Fri Feb 23 20:10:02 +0000 2018
# 11  Fri Feb 23 20:10:06 +0000 2018
# 12  Fri Feb 23 20:10:07 +0000 2018
# 13  Fri Feb 23 20:10:07 +0000 2018
# 14  Fri Feb 23 20:10:07 +0000 2018
# 15  Fri Feb 23 20:10:07 +0000 2018
# 16  Fri Feb 23 20:10:10 +0000 2018
# 17  Fri Feb 23 20:10:10 +0000 2018
# 18  Fri Feb 23 20:10:12 +0000 2018
# 19  Fri Feb 23 20:10:12 +0000 2018
# 20  Fri Feb 23 20:10:15 +0000 2018
# 21  Fri Feb 23 20:10:17 +0000 2018
# 22  Fri Feb 23 20:10:17 +0000 2018
# 23  Fri Feb 23 20:10:18 +0000 2018
# 24  Fri Feb 23 20:10:19 +0000 2018
# 25  Fri Feb 23 20:10:20 +0000 2018
# 26  Fri Feb 23 20:10:21 +0000 2018
# 27  Fri Feb 23 20:10:25 +0000 2018
#
#                                                  text
# 0   4 Full Days of Training, Talks, Workshop and N...
# 1   made a thing in Drawbot to make rotating deskt...
# 2   @KikiDlamini The meaning of life is just so re...
# 3   Scaling up data quality. Start small but think...
# 4   RT @ericasadun: Pop a little Python Inter-Op i...
# 5   RT @ProgrammingWrld: Pay what you want for 50+...
# 6   RT @janhjensen: Awesome Python Chemistry https...
# 7   With the @sloansportsconf going on right now I...
# 8   RT @northumbriana: This is a real BBC document...
# 9   RT @plotlygraphs: ICYMI: Fully interactive D3 ...
# 10  #Python - @property decorator is Python way to...
# 11  4 Ways Real-time Big Data Improves Pharma’s Bo...
# 12  Become a WiDS Broadcaster and share the #WiDS2...
# 13  Python and Django Full Stack Web Developer Boo...
# 14  RT @mitpress: Science’s Inference Problem: Whe...
# 15  RT @PulseGhana: Video: Commotion erupts as pas...
# 16  Check out Drama, the breezy and brilliant new ...
# 17  As machines get smarter, this doesn’t surprise...
# 18  … Emergency drills, early warning systems, and...
# 19  @dabeaz In mobile it's very common for a game/...
# 20  Big Companies Are Embracing Analytics, But Mos...
# 21  @python NowTime: 2018/02/24 05:10:17.3015\nTwe...
# 22  @python NowTime: 2018/02/24 05:10:17.6045\nTwe...
# 23  RT @gehlinstitute: "When we think about the ro...
# 24  @python NowTime: 2018/02/24 05:10:19.4431\nTwe...
# 25  RT @kirstendanis: ✨JOB✨\nAmbitious visual jour...
# 26  Python 3’s range is more powerful than Python ...
# 27  Full-Stack Developer | PHP, ASP, Python, HTML,...

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#            word  count
# 0         https     26
# 1            co     25
# 2        python     18
# 3           and     13
# 4            rt      9
# 5           the      8
# 6            to      8
# 7            of      6
# 8          data      6
# 9            in      6
# 10           it      5
# 11           we      5
# 12           is      4
# 13          big      4
# 14          for      4
# 15         2018      4
# 16           24      3
# 17          out      3
# 18         from      3
# 19         full      3
# 20           10      3
# 21        think      3
# 22         this      3
# 23      nowtime      3
# 24          but      3
# 25   tweetcount      3
# 26      science      3
# 27           as      3
# 28           02      3
# 29         with      3
# 30         when      3
# 31           05      3
# 32           on      3
# 33         what      3
# 34           17      2
# 35        check      2
# 36      meaning      2
# 37           ai      2
# 38        could      2
# 39           or      2
# 40         your      2
# 41  inspiration      2
# 42     training      2
# 43      systems      2
# 44        doesn      2
# 45        stack      2
# 46          has      2
# 47           so      2
# 48         real      2
# 49          get      2
